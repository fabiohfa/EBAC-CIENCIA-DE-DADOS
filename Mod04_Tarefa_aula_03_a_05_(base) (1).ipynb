# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
data.columns

# %%
data = df_mat
data.columns = ['acertos Matemática']

# %%
data['acertos Português'] = df_por
data['acertos Geografia'] = df_geo
data['acertos Inglês'] = df_ing
data['acertos História'] = df_his
data['acertos Física'] = df_fis
data['acertos Química'] = df_qui
gabarito = [24,18,8,8,8,12,12]
materias = ["Matemática","Português","Geografia","Inglês","HIstória","Física","Química"]
data,
# Out:
# (    acertos Matemática  acertos Português  acertos Geografia  acertos Fisica  \
#  0                    6                  7                  7               8
#  1                   19                 10                  0              11
#  2                   14                 16                  0               4
#  3                   10                  7                  3               0
#  4                    7                  2                  2               9
#  ..                 ...                ...                ...             ...
#  95                   6                  4                  7               9
#  96                   8                  1                  4               4
#  97                  23                  5                  0               1
#  98                   0                 10                  3              10
#  99                  11                 15                  0               7
#
# ...

# %%
pd.DataFrame(gabarito).T

# %%
data.iloc[:,0]
# Out:
# 0      6
# 1     19
# 2     14
# 3     10
# 4      7
#       ..
# 95     6
# 96     8
# 97    23
# 98     0
# 99    11
# Name: acertos Matemática, Length: 100, dtype: int32

# %%
# 1) Seu código aqui
for i in range(len(materias)):
    data['% ' + materias[i]] = round((data.iloc[:,i]/gabarito[i])*100,2)
acertos = data.loc[:,"% Matemática":]
acertos
# Out:
#     % Matemática  % Português  % Geografia  % Inglês  % HIstória  % Física  \
# 0          25.00        38.89         87.5     100.0        12.5     25.00
# 1          79.17        55.56          0.0     137.5         0.0      0.00
# 2          58.33        88.89          0.0      50.0        87.5     41.67
# 3          41.67        38.89         37.5       0.0         0.0     33.33
# 4          29.17        11.11         25.0     112.5         0.0     58.33
# ..           ...          ...          ...       ...         ...       ...
# 95         25.00        22.22         87.5     112.5        50.0      8.33
# 96         33.33         5.56         50.0      50.0        12.5     50.00
# 97         95.83        27.78          0.0      12.5        50.0     16.67
# 98          0.00        55.56         37.5     125.0        62.5      8.33
# 99         45.83        83.33          0.0      87.5        75.0      8.33
#
#     % Química
# 0       25.00
# 1       66.67
# 2       33.33
# ...

# %%
# 2) Seu código aqui
data['Total acertos'] = data['acertos Fisica']+data['acertos Geografia']+data['acertos História']+data['acertos Inglês']+data['acertos Matemática']+ data['acertos Português'] + data['acertos Química']
total_acertos = data['Total acertos']
total_acertos = pd.DataFrame(total_acertos)
total_acertos
# Out:
#     Total acertos
# 0              35
# 1              48
# 2              50
# 3              32
# 4              30
# ..            ...
# 95             34
# 96             27
# 97             40
# 98             40
# 99             42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
data['percent_total'] = round((data['Total acertos']/sum(gabarito))*100,2)
data['percent_total']
# Out:
# 0     38.89
# 1     53.33
# 2     55.56
# 3     35.56
# 4     33.33
#       ...
# 95    37.78
# 96    30.00
# 97    44.44
# 98    44.44
# 99    46.67
# Name: percent_total, Length: 100, dtype: float64

# %%
# 4) Seu código aqui
alunos_acima_45 = len(total_acertos.loc[total_acertos['Total acertos'] > 45])
alunos_acima_45
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
desqualificados = (data.loc[(data['acertos Matemática'] == 0) | (data['acertos Química'] == 0) | (data['acertos Fisica'] == 0)])
desqualificados
# Out:
#     acertos Matemática  acertos Português  acertos Geografia  acertos Fisica  \
# 3                   10                  7                  3               0
# 6                    6                  0                  7               0
# 10                  10                  8                  3               7
# 12                  20                  8                  3               0
# 14                   7                 11                  1               4
# 20                  23                 11                  6               2
# 25                   0                  4                  7               4
# 26                  11                 14                  6               0
# 27                  21                 13                  1               3
# 33                  14                  8                  0               6
# 35                  11                 14                  6               0
# ...

# %%
len(desqualificados)
# Out:
# 23

# %%
media_hist = desqualificados.loc[:,'acertos História'].sum()/gabarito[4]
media_geo = desqualificados.loc[:,'acertos Geografia'].sum()/gabarito[4]
media_geo, media_hist
# Out:
# (9.25, 9.875)

# %%
segunda_fase = data.loc[(data['Total acertos']>45) & (data['acertos Matemática'] != 0) & (data['acertos Química'] != 0) & (data['acertos Fisica'] != 0)]
segunda_fase
# Out:
#     acertos Matemática  acertos Português  acertos Geografia  acertos Fisica  \
# 1                   19                 10                  0              11
# 2                   14                 16                  0               4
# 5                   20                  2                  5               9
# 7                   18                  4                  4               1
# 8                   22                  9                  2               5
# 17                  21                 15                  2               2
# 18                  20                  4                  3              11
# 24                  20                  2                  7              11
# 31                  15                 13                  3               9
# 36                  22                  9                  6               4
# 37                  19                 12                  5               6
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = str('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-2c5245d7-971f-426e-a26f-54eb4550d796.c000.csv')
#'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-5ed92752-6121-474f-ab37-816918134afc.c000.csv' - link com problema de acesso

# %%
dados = pd.read_csv(arquivo) # Leitura dando erro, irei realizar o download do arquivo e obtenção dos dados através do read_csv
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 dados = pd.read_csv(url_decoded)
#
# File c:\Users\fabio\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
dados = pd.read_csv('G:\Meu Drive\PESSOAL\MEUS DOCUMENTOS\EDUCAÇÃO\CURSOS\[EBAC] CIÊNCIA DE DADOS\Desenvolvimento em Ciência de Dados e Metodologia Crisp-DM\MÓDULO5 - PANDAS\Datasus - Acre.csv',sep=';')
dados
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\fabio\AppData\Local\Temp\ipykernel_21460\929193039.py:1: SyntaxWarning: invalid escape sequence '\M'
#   dados = pd.read_csv('G:\Meu Drive\PESSOAL\MEUS DOCUMENTOS\EDUCAÇÃO\CURSOS\[EBAC] CIÊNCIA DE DADOS\Desenvolvimento em Ciência de Dados e Metodologia Crisp-DM\MÓDULO5 - PANDAS\Datasus - Acre.csv',sep=';')
#                                       document_id  \
# 0       a9999721-43c0-422e-ae5c-1cc2d4cfe07e-i0b0
# 1       dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 2       db58f53d-8f33-42a6-8829-0abe00389a73-i0b0
# 3       dd180d26-5bee-44d5-a4d5-ea314976d7f1-i0b0
# 4       e9b5c1d8-471f-400c-9c3b-2db45ce4b1be-i0b0
# ...                                           ...
# 390906  c7c7cce0-2d32-4eec-8ac3-c49d07ab2151-i0b0
# 390907  c8167edf-8201-44c7-b132-26e5b8eeeeea-i0b0
# 390908  c827daac-9eae-493d-92fe-f980426db74f-i0b0
# 390909  c84f3cfe-827c-472e-aa92-5c999b791070-i0b0
# ...

# %%
dados.head(5)
# Out:
#                                  document_id  \
# 0  a9999721-43c0-422e-ae5c-1cc2d4cfe07e-i0b0
# 1  dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 2  db58f53d-8f33-42a6-8829-0abe00389a73-i0b0
# 3  dd180d26-5bee-44d5-a4d5-ea314976d7f1-i0b0
# 4  e9b5c1d8-471f-400c-9c3b-2db45ce4b1be-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  0a6fa8fc037435e78d5476f4995fc25bb1c716cc370676...              27
# 1  5310f2da2074b4d20620f811323a6f7c4fc8853fc5a41f...              22
# 2  05e7be6e9ef6b7666ff8d28eddf6d7f76154860dcce2b7...              62
# 3  d0a264fe07e8b95225c45d61cd6f1c020c1dec5d5f1125...              68
# 4  1b5a54c96f4fef5ba65535e12cb92502e98f7bd96a31a1...              39
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1993-08-16                          M                        3
# 1              1998-08-09                          F                       99
# ...

# %%
# 1) Sua solução aqui
dados['vacina_nome'].unique()
# Out:
# array(['COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#        'COVID-19 PFIZER - COMIRNATY', 'COVID-19 JANSSEN - Ad26.COV2.S',
#        'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#        'COVID-19 PFIZER - COMIRNATY BIVALENTE',
#        'COVID-19 SINOVAC - CORONAVAC',
#        'COVID-19 PEDIÁTRICA - PFIZER COMIRNATY', 'INF3',
#        'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#        'COVID-19 ASTRAZENECA - ChAdOx1-S', 'COVID-19 MODERNA - SPIKEVAX',
#        'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS',
#        'COVID-19 MODERNA', 'VVBN', nan, 'INF4'], dtype=object)

# %% [markdown]
# Existem 15 registros de nomes de vacinas neste banco de dados, entretanto, em uma primeira análise dos valores únicos é possível verificar que existem dados faltantes "nan" e nomes que talvez não representem a informação correta dos tipos de vacinas. Analisando os dados é possível utilizar a coluna "vacina_codigo" para identificar de forma mais precisa quantos tipos de vacinas existem

# %%
dados['vacina_nome'].nunique()
# Out:
# 15

# %%
dados['vacina_codigo'].unique()
# Out:
# array([ 85,  87,  88,  86, 103,  98,  99,  33,  89,  97, 102, 100,  77],
#       dtype=int64)

# %%
dados['vacina_codigo'].nunique()
# Out:
# 13

# %%
dados_s_duplicados = dados.drop_duplicates(subset='vacina_nome')
dados_s_duplicados.head(5)
# Out:
#                                   document_id  \
# 0   a9999721-43c0-422e-ae5c-1cc2d4cfe07e-i0b0
# 1   dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 4   e9b5c1d8-471f-400c-9c3b-2db45ce4b1be-i0b0
# 5   dd299152-6a68-42c8-8503-8115657fc6bd-i0b0
# 15  ddb919ff-3668-4f03-be75-d094f4ae8dff-i0b0
#
#                                           paciente_id  paciente_idade  \
# 0   0a6fa8fc037435e78d5476f4995fc25bb1c716cc370676...              27
# 1   5310f2da2074b4d20620f811323a6f7c4fc8853fc5a41f...              22
# 4   1b5a54c96f4fef5ba65535e12cb92502e98f7bd96a31a1...              39
# 5   b6406ba07d8d7fb42da161da8474dd643b3c08864b6446...              32
# 15  d432be68038b17980750cc494f7a73580f16f59cfe98f6...              67
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 0               1993-08-16                          M
# 1               1998-08-09                          F
# 4               1983-05-08                          F
# ...

# %%
dados[dados['vacina_nome'].isna()]
# Out:
#                                       document_id  \
# 43156   10cb6df2-8824-4bd8-8c79-820aba3a39f2-i0b0
# 110291  c5934b3d-1ed6-4d31-8c34-3e0a30a36443-i0b0
# 115704  cccc387f-0e8a-49aa-9122-bfb87a320366-i0b0
# 138855  19322f34-6162-4508-ae51-ae03a07e7873-i0b0
# 142976  1106bbca-bbfb-430e-ab7b-7853725a04b5-i0b0
# 143376  d9de2c20-cf6d-4c1e-88cc-21152dc720de-i0b0
# 213299  20bffa60-82c9-4449-bafc-8ec8f4862359-i0b0
# 323034  445361a5-745e-4cd2-87a9-77e69e0d1898-i0b0
# 369051  60642a8c-8887-4efc-be95-c655623faed3-i0b0
#
#                                               paciente_id  paciente_idade  \
# 43156   7bf67df96c3f933c1027520b3d1b46d6c66006cbb9ea0f...               2
# 110291  2502c2447172d90b9e09c45084fd618e4be2455d9aa604...               3
# 115704  6756c6c362019fb48008a298061132eedb681db0acce5a...               1
# 138855  5b8bb3ff6891d4b8bf6bcbde39d32852bd44ee0edd786d...               2
# 142976  8c29b07cb4b2d7ed9273cddb03e7238e35e540f1b44275...               3
# ...

# %%
dados_s_duplicados = dados_s_duplicados.loc[:,'vacina_codigo':'vacina_nome']
dados_s_duplicados
# Out:
#         vacina_codigo                                        vacina_nome
# 0                  85          COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD
# 1                  87                        COVID-19 PFIZER - COMIRNATY
# 4                  88                     COVID-19 JANSSEN - Ad26.COV2.S
# 5                  86              COVID-19 SINOVAC/BUTANTAN - CORONAVAC
# 15                103              COVID-19 PFIZER - COMIRNATY BIVALENTE
# 44                 98                       COVID-19 SINOVAC - CORONAVAC
# 65                 99             COVID-19 PEDIÁTRICA - PFIZER COMIRNATY
# 105                33                                               INF3
# 231                99             COVID-19 PFIZER - COMIRNATY PEDIÁTRICA
# 238                89                   COVID-19 ASTRAZENECA - ChAdOx1-S
# 339                97                        COVID-19 MODERNA - SPIKEVAX
# 554               102  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D...
# ...

# %% [markdown]
# Ao final desse segundo tratamento podemos identificar que a vacina com "nome" nan pode ter apresentado a falta no nome por algum tipo de erro no registro, mas é possível identificar através do código qual tipo de vacina é, na filtragem feita acima o "Nan" possui o mesmo cógido que a vacina "COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR D", logo podemos, inclusive excluir esses registros do banco de dados (dependendo do tipo de estudo que for ser realizado com ele) sem que afete analises estatisticas por exemplo pois é apenas 9 vacinas em um universo de mais de 300 mil. Já o código 97 possui dois nomes parecidos, mas que muda um detalhe no final, o que é sufiente para o pandas entender que tratam de informações distintas, logo neste caso faltou uniformidade na forma como os dados foram computados.

# %%
# 2)
dados['paciente_id'].nunique()
# Out:
# 318850

# %%
# 3)
pacientes_1_dose = dados[dados['vacina_descricao_dose'] == '1ª Dose']
pacientes_1_dose['document_id'].nunique()
# Out:
# 144117

# %%
# 3) solução alternativa
pacientes_alternativo = dados
pacientes_alternativo['1_dose'] = 0
pacientes_alternativo.loc[pacientes_alternativo['vacina_descricao_dose'] == '1ª Dose', '1_dose' ] = 1
pacientes_alternativo['1_dose'].sum()
# Out:
# 144117

# %%
dados.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem', '1_dose'],
# ...

# %%
# 4)
len(dados[dados['paciente_idade']< 18])
# Out:
# 79220

# %%
# 5)Quantos estabelecimentos aplicaram vacina no Acre?
dados['estabelecimento_valor'].unique()
# Out:
# array([2002272, 2002876, 6917291, 3810771, 2000040, 2002914, 6159087,
#        3323293, 2001349, 2002221, 2001101, 5981891, 2000237, 2001217,
#        2000954, 2001314, 2000504, 2002132, 2000059, 2000016, 3006166,
#        3007367, 2000202, 2000598,  924490, 2001039, 2000938, 3544915,
#        2000326, 2000075, 6992811, 2000156, 6934013, 2002922, 2003155,
#        2000415, 2000067, 6612385, 2000660, 6568629, 3797554, 2003066,
#        2002299, 3449432, 9014896, 2000962, 2001454, 2001225, 6289312,
#        2000318, 5354072, 6697151, 2001896, 6430201, 2002566, 7168748,
#        2001772, 7139454, 5710111, 2000628,  468363, 7375913, 2002884,
#        2000091, 2001748, 6308740, 2000555, 7014147, 3323307, 9648968,
#        2000342, 6917682, 2000482, 2001128, 2000873, 7797494, 3541592,
#        7232489, 3959082, 6428940, 2000547, 2000865, 2000105, 7799632,
#        2000334, 2000571, 2001934, 9294449, 2002906, 7818092, 5174678,
# ...

# %%
dados['estabelecimento_valor'].nunique()
# Out:
# 229

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
copia_dados = dados.loc[dados['paciente_idade']<18]
copia_dados.head()
# Out:
#                                   document_id  \
# 10  af6333da-504a-44c4-8284-79c3ded62ba8-i0b0
# 12  f4d11da9-c6f2-4fae-a4f4-6874edea5c4a-i0b0
# 18  a8653b73-75a7-4d58-92f6-846f1ab48980-i0b0
# 19  ddbe8e75-ac1e-40b7-ad55-ead506189efd-i0b0
# 36  d856c6c8-e7f8-4f64-a82b-0d2783cf27de-i0b0
#
#                                           paciente_id  paciente_idade  \
# 10  3de373ed4c63d13378f92d6c13fdebe2d5a11382468230...               3
# 12  c8880e06c1cbdb23d61d5750f3822d1731f2eab81e6323...              16
# 18  58b6681a766949cd392f7df765cc2a16fc9996a0f44f6d...               4
# 19  4a502fc943b8e62deca3f6cd1be3885f7b0d8a2ed88796...              14
# 36  b02faac4236b19d694a1b31e3674e9e5f4ff5e111d8f95...              14
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 10              2019-05-02                          F
# 12              2005-04-11                          F
# 18              2018-09-17                          M
# ...

# %%
# 2)
copia_dados.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem', '1_dose'],
# ...

# %%
# 3)
copia_dados['vacina_categoria_nome'].nunique()
# Out:
# 14

# %%
# 4)
lista_estab = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
# 5)
dados_final = copia_dados.loc[:,['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']]

# %%
# Out:
#         estabelecimento_valor                  estabelecimento_razaoSocial  \
# 10                    2000040                PREFEITURA MUNICIPAL DE FEIJO
# 12                    6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 18                    6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                    2001349            PREFEITURA MUNICIPAL DE BRASILEIA
# 36                    2001314       PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# ...                       ...                                          ...
# 390888                3015548           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390897                2002914      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 390902                7014147                PREFEITURA MUNICIPAL DE FEIJO
# 390904                6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390910                2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
#
#                                  estalecimento_noFantasia  \
# ...

# %%
dados_ec_unicos = dados_final.drop_duplicates()
dados_ec_unicos
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 10                    2000040               PREFEITURA MUNICIPAL DE FEIJO
# 12                    6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                    2001349           PREFEITURA MUNICIPAL DE BRASILEIA
# 36                    2001314      PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 42                    2002876                SECRETARIA MUNCIPAL DE SAUDE
# ...                       ...                                         ...
# 205212                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 236654                4646770                           USF SAO FRANCISCO
# 340161                6411312   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 357211                2000814       SECRETARIA DE ESTADO DE SAUDE DO ACRE
# 370287                2832798      PREFEITURA MUNICIPAL DE EPITACIOLANDIA
#
#                                  estalecimento_noFantasia  \
# ...
